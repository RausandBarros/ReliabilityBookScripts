# %% [markdown]
# ## The Lognormal Distribution

# %%
t<-seq(0, 10, length=300) # Set the time axis
# Set the parameters
nu<-5
tau<-2
# Calculate the lognormal density y for each t
y<-dlnorm(t, nu, tau, log=FALSE)
plot(t, y, type="l")
# Out:
# plot without title
