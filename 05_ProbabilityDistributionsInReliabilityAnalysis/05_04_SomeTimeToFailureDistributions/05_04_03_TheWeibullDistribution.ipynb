# %% [markdown]
# ## The Weibull distribution

# %%
t<-seq(0, 1000, length=300) # Set time axis
# Set the parameters
a<-2.5    # shape parameter (alpha)
th<-200   # scale parameter (theta)
# Calculate the Weibull density (y) for each t
y<-dweibull(t, a, th, log=FALSE)
plot(t, y, type="l")
# Out:
# plot without title
