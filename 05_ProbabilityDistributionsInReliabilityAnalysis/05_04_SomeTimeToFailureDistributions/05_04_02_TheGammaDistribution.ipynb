# %% [markdown]
# ## The gamma probability density function

# %%
t<-seq(0, 6, length=300) # Set time axis
# Set the parameters
a<-2         # shape
rate<-1      # rate
# Calculate the gamma density (y) for each t
y<-dgamma(t, a, rate, log=FALSE)
plot(t, y, type="l")
# Out:
# plot without title

# %% [markdown]
# ## The survivor function

# %%
t<-seq(0, 6, length=300)
# Set time axis
# Set the parameter
a<-2        # shape
rate<- 1    # rate
# Calculate the survivor function (y) for each t
y<-1-pgamma(t, a, rate, log=FALSE)
plot(t, y, type="l")
# Out:
# plot without title

# %% [markdown]
# ## The failure rate function

# %%
t<-seq(0, 6, length=300) # Set time axis
# Set the parameter
a<-2       # shape
rate<-1
# Calculate the failure rate function (y) for each t
y<-dgamma(t, a, rate, log=FALSE)/(1-pgamma(t, a, rate, log=FALSE))
plot(t, y, type="l")
# Out:
# plot without title
