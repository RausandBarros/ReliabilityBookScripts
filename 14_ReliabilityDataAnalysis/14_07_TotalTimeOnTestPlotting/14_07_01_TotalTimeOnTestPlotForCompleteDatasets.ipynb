# %% [markdown]
# ## Total-Time-On-Test-Plot For Complete Datasets

# %%
library(AdequacyModel)

# %%
# Enter the dataset
data <- c(17.88, 28.92, 33.00, 41.52, 42.12, 45.60, 48.40, 51.84, 51.96, 54.12,
          55.56, 67.80, 68.64, 68.64, 68.88, 84.12, 93.12, 98.64, 105.12, 105.85,
          127.92, 128.04, 173.40)

# %%
# Make the TTT plot
TTT(data, lwd=1.5, grid=FALSE, lty=3)
# Out:
# Plot with title “”

# %% [markdown]
# ### Example 2

# %%
# Generate a random sample from a Weibull distribution
data<-rweibull(8000, 3, scale=1)

# %%
# Make the TTT transform
TTT(data, lwd=1.5, grid=FALSE, lty=3)
# Out:
# Plot with title “”
