# %% [markdown]
# ## Histogram

# %%
survtime<-read.table("14_03_dataset.txt", header=FALSE, dec=".") # Data loading

# %%
for (nBreaks in c(3, 5, 10)) {
    hist(survtime[ ,'V1'], breaks=nBreaks, freq=FALSE, col="cornflowerblue") # Plots the histogram
}
# Out:
# Plot with title “Histogram of survtime[, "V1"]”
# Plot with title “Histogram of survtime[, "V1"]”
# Plot with title “Histogram of survtime[, "V1"]”
