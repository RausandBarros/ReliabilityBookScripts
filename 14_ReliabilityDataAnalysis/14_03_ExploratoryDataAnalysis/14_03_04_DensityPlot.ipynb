# %% [markdown]
# ## Density plot

# %%
survtime <-read.table("14_03_dataset.txt", header=F, dec=".")
d <- density(survtime[, 'V1']) # Returns the density data
plot(d) # Plots the results
# Out:
# Plot with title “density.default(x = survtime[, "V1"])”
