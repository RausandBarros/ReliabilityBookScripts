# %% [markdown]
# ## Q-QPlot

# %%
# Data loading
survtime<-read.table("14_03_dataset.txt", header=FALSE, dec=".")

# %%
# Normal Q-Q Plot
qqnorm(survtime[ ,'V1'])
qqline(survtime[ ,'V1'])
# Out:
# Plot with title “Normal Q-Q Plot”

# %%
# Exponential Q-Q Plot
qqplot(rexp(300, rate=1), survtime[ ,'V1'])
# Out:
# plot without title
